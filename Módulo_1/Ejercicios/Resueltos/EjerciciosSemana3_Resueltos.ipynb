# %% [markdown]
# ## Ejercicio 1:
#
# Escribir un código que tome una lista de cadenas y que imprima la cadena más larga de la lista.

# %%
#Defino la variable donde guardar el input en forma lista (le impongo que lo tome como string, y que separe con comas)
lista_cadenas = str(input("Darme una lista de palabras separadas con comas, por favor:")).split(',')

print("El elemento más largo es:", max(lista_cadenas, key = len)) 
#agrego el argumento para que use como 'llave' (key) len, por length de 'largo' en inglés
# Out:
# Darme una lista de palabras separadas con comas, por favor:hola,gol,casas
# El elemento más largo es: casas

# %% [markdown]
# ## Ejercicio 2:
#
# Escribir un código que tome dos listas como entrada y que cree una nueva lista conteniendo sólo los elementos en común que están en las dos listas.
#
# **Nota:** no te preocupes por el tema de que pueden haber elementos duplicados en las listas.

# %%
lista_1 = str(input("Dame una lista de cosas separadas sólo por comas, por favor:")).split(',')
lista_2 = str(input("Dame una segunda lista de cosas separadas sólo por comas, por favor:")).split(',')

#Pido separador en los inputs, paso todo a lowercase, y separo según lo que especifiqué

lista_en_comun = [] #genero una lista vacía donde voy a poner los elementos compartidos

for valor in lista_1:                                     #recorro cada valor de una de las listas
  if valor in lista_2:                                    #continúo sólo si se cumple que ese valor está en la otra lista
    lista_en_comun.append(valor)                          #agrego el elemento en la lista vacía
print("Los elementos en común son:", lista_en_comun)      #imprimo la lista donde guardé los elementos en común

#OJO: si en el input ponemos dato1_input+coma+espacio+dato2_input NO va a funcionar, si ponemos dato1+espacio+dato2 hay que cambiar a split(), etc
# Out:
# Dame una lista de cosas separadas sólo por comas, por favor:hola,tal
# Dame una segunda lista de cosas separadas sólo por comas, por favor:hola,hola,tal
# Los elementos en común son: ['hola', 'tal']

# %% [markdown]
# ## Ejercicio 3:
#
# Escribir un programa que imprima los primeros diez números de la sucesión de Fibonacci. La sucesión de Fibonacci es una secuencia de números donde cada elemento es la suma de los dos anteriores, y se comienza con el 0 y el 1.

# %%
#Hay varias maneras, a mi se me ocurre definir los primeros dos valores, y los que siguen
#definirlos de manera iterativa, es decir, tomando los valores que ya existen dentro 
#de la lista en la cual voy guardando la sucesión

j = []                    #generamos una lista vacía donde voy a poner los valores de la serie
for i in range(10):
  if i == 0:
    j.append(i)           #el primer término está definido como cero, lo agrego a la lista
  elif i == 1:            #el segundo también
    j.append(1)
  else:                   #el resto los defino según los valores previos: " cada elemento es la suma de los dos anteriores"
    f = j[-2] + j[-1]     #Tomo el último y anteúltimo valor contando desde atrás con -1, -2
    j.append(f)
print(j)

# %% [markdown]
# ## Ejercicio 4:
#
# Escribir un programa que tome una cadena como entrada y cuente la cantidad de vocales que hay en ella.

# %%
#Defino las vocales que tengo que buscar
vocales = ['a', 'e', 'i', 'o', 'u']
#Pido que escriban cadena, y convierto todo a lowercase (otra alternativa sería poner en vocales A,a, e, E etc)
cadena = "hola mundo"

contador_de_vocales = 0         #por default, que sean cero y a esto le sumo cada vez que haya coincidencia de vocal

for letra in cadena:
  if letra in vocales:
    contador_de_vocales = contador_de_vocales + 1
print(contador_de_vocales)
# Out:
# 4

# %% [markdown]
# ## Ejercicio 5:
#
# Escribir un programa que tome una lista de palabras (cadenas) y que imprima sólo aquellas que son palíndromos.

# %%
#Palíndromo es que sean iguales de delante que de revés, entonces vamos a pedirle que de vuelta la palabra recorriendola cada -1 pasos

#Input de palabras a chequear, separadas por coma, todas en lowercase
candidatos_palindromo = str(input("Dame una lista de cosas separadas sólo por comas, por favor:")).lower().split(',')

palindromos = []                        #lista vacía donde voy a guardar palabras palindromas
for candidato in candidatos_palindromo:
  reverso = candidato[::-1]             #guardo en la variable 'reverso' la palabra dada vuelta al recorrerla cada -1 lugares                       
  if reverso == candidato:              #condición de palíndromo
    palindromos.append(candidato)       #sólo si son iguales, se actualiza palindromos agregando la palabra en la que se encuentra iterando el for

print("Estas palabras son palindromos:",palindromos)

#Alternativa más completa: condicionar la impresión de la variable según haya o no palíndromas
print("Segunda alternativa de código:")
if len(palindromos)>0:
  print("Estas palabras son palindromos:",palindromos)
else:
  print("Ninguna de tus palabras era palindromo")
# Out:
# Dame una lista de cosas separadas sólo por comas, por favor:hola,casa,asa
# Estas palabras son palindromos: ['asa']
# Segunda alternativa de código:
# Estas palabras son palindromos: ['asa']

# %% [markdown]
# ## Ejercicio 6:
#
# El siguiente código tiene un problema. ¿Podés identificar cuál es y corregirlo?

# %%
numero = 10.2

if (numero % 2) == 1:
  print('El número es impar')
elif (numero % 2) == 0:
  print('El número es par')
else:
  print('El número ', numero, 'no es ni par ni impar. Es decimal')
# Out:
# El número  10.2 no es ni par ni impar. Es decimal

# %%
#UNA CORRECCION POSIBLE
numero = float(input())                   #esto para probar con cualquier número (decimal incluso)
if (numero % 2) == 1:
  print('El número ', numero, ' es impar')
elif (numero % 2) == 0:
  print('El número ', numero, '  es par')
#por cómo está indentado, acá empieza de vuelta este nuevo if. Y encima tenemos las mismas condiciones
else:
  print('El número ', numero, 'no es ni par ni impar. Hay algo raro...')
# Out:
# 4.3
# El número  4.3 no es ni par ni impar. Hay algo raro...

# %% [markdown]
# ## Ejercicio 7:
#
# El siguiente código también tiene un problema. ¿Podés identificar cuál es y corregirlo?

# %%
palabra = 'Cocos'

if 'a' or 'A' in palabra:
  print(f'La palabra \"{palabra}\" contiene una \"a\"')
else:
  print(f'La palabra \"{palabra}\" no contiene una \"a\"')
# Out:
# La palabra "Cocos" contiene una "a"

# %%
#Las condiciones múltiples deben estar bien expresadas cada una.

palabra = 'Cocos'

if ('a' in palabra) or ('A' in palabra):
  print(f'La palabra \"{palabra}\" contiene una \"a\"')
else:
  print(f'La palabra \"{palabra}\" no contiene una \"a\"')
# Out:
# La palabra "Cocos" no contiene una "a"

# %%
# fijate que el siguiente if se cumple:
if 'a' :
  print('Verdadero')
# porque el valor booleano de 'a', bool('a'), es True al ser una cadena no vacía
# Out:
# Verdadero

# %% [markdown]
# ## Ejercicio 8:
#
# *FizzBuzz* es un juego de palabras grupal para que los niños aprendan sobre la división, pero se suele usar como un ejercicio clásico de programación. En el juego los jugadores se turnan para contar de forma incremental, reemplazando cualquier número divisible por tres con la palabra "fizz", y cualquier número divisible por cinco con la palabra "buzz", y cualquier número divisible por 3 y 5 con la palabra "fizzbuzz".
#
# Hace un programa que imprima los números del 1 al 30, pero reemplazando los múltiplos de 3 y/o 5 por "fizz", "buzz" ó "fizzbuzz" siguiendo las reglas del juego.

# %%
contamos_hasta_el_numero = 30

for i in range(1, contamos_hasta_el_numero +1):    #si queremos que llegue al 30, hay que pedirle el número +1
  if (i%5 == 0 and i%3 == 0):                     # pongo la condición doble primero, sino imprimo sólo fizz al cumplirse la primera condicion y pasar al siguiente i
    print('fizzbuzz')
  elif i%3 == 0:
    print('fizz')
  elif i%5 ==0:
    print('buzz')
  else:
    print(i)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz

# %% [markdown]
# ## Ejercicio 9:
# En base a las listas ficticias de alumnos, con datos como nombre, apellido, y nota (calificación).
#
# Escribir un programa que:
#
# * Imprima la nombre y apellido de los alumnos de manera ordenada alfabéticamente por el apellido
# * Calcule el promedio de notas de la cursada, e informe la nota máxima y la mínima.
# * Genere una variable llamada "aprobados" con un a lista de alumnos aprobados (se aprueba con 7)
# * Genere una variable (lista) conteniendo valores booleanos (True/False), que corresponda a los alummnos aprobados (`True`) o desaprobados (`False`)
#
# *NOTA: el orden de las listas es el mismo, vale decir, la nota de Laura Pérez es 7, y asi sucesivamente.*

# %%
nombres = ['Laura', 'Juan', 'Tomás', 'Ana', 'Diego', 'Carla', 'Kim', 'Sofía']
apellidos = ['Pérez', 'Isla', 'Gómez', 'Castro', 'Roca', 'Romero', 'Díaz', 'López']
notas = [7, 4, 9, 5, 7, 8, 6, 10]


# Tu codigo
#Inicializo las listas donde voy a cargas los valores que correspondan
nombres_completos = []
aprobados = []
lista = []

for i in range(len(nombres)):                             #acá recorro ok porque todas las listas tienen el mismo largo, ojo en otros casos donde hay que recorrerlos con dos 'for'
  apellido_nombre = apellidos[i]+', ' + nombres[i]         #concateno con apellido primero y separado por coma y espacio
  if notas[i]>=7:
    aprobados.append(apellido_nombre) 
                            #agrego el que acabo de unir
  lista.append(notas[i]>=7)
  nombres_completos.append(apellido_nombre)

nombres_completos_ordenados = sorted(nombres_completos)       #ordeno (por apellido, que está primero) fuera del for porque sino lo ordena a cada paso y seria retrasar el programa con algo que puede hacerse al final
print('Lista de nombres completos ordenados según apellidos', nombres_completos_ordenados)

print('El promedio de la clase es:', sum(notas)/len(notas))#promedio = 

print('La nota mínima es:', min(notas))
print('La nota máxima es:', max(notas))
print('Estudiantes aprobados: ', aprobados)
print('Del orden original, \n', nombres_completos,  '\n aprobaron: \n',lista)
# Out:
# Lista de nombres completos ordenados según apellidos ['Castro, Ana', 'Díaz, Kim', 'Gómez, Tomás', 'Isla, Juan', 'López, Sofía', 'Pérez, Laura', 'Roca, Diego', 'Romero, Carla']
# El promedio de la clase es: 7.0
# La nota mínima es: 4
# La nota máxima es: 10
# Estudiantes aprobados:  ['Pérez, Laura', 'Gómez, Tomás', 'Roca, Diego', 'Romero, Carla', 'López, Sofía']
# Del orden original,
#  ['Pérez, Laura', 'Isla, Juan', 'Gómez, Tomás', 'Castro, Ana', 'Roca, Diego', 'Romero, Carla', 'Díaz, Kim', 'López, Sofía']
#  aprobaron:
#  [True, False, True, False, True, True, False, True]

# %%
#NOTA: El nombre completo puede hacerse de manera más corta con 'list comprehension' que todavía no vimos
nom_com = [(nom+ ' ' + ap) for nom, ap in zip(nombres, apellidos)]
nom_com
