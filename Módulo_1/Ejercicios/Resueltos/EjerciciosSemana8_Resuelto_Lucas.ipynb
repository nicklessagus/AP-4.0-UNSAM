# %% [markdown]
# # Ejercicios Semana 8
#
# Para ejercitar Pandas

# %% [markdown]
# ## Ejercicio 1:
# Leer el archivo de datos llamado [estaciones_metereologicas.csv](https://drive.google.com/file/d/1l7H9hdYAzsnXONbmsP2sKb2GRDel80eo/view?usp=share_link) como un un dataframe de Pandas. A partir de este vamos a:
#
# 1. Mostrar las primeras filas del dataframe.
# 2. Mostrar el número total de filas y columnas.
# 3. Calcular la media, desviación estándar, valor mínimo y valor máximo de la columna `'altura'`.

# %%
# Conectar Drive a Colab
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#os.chdir('/content/drive/MyDrive/Argentina-programa')
os.chdir('/content/drive/MyDrive/Colab Notebooks/Data/')

# %%
import pandas as pd

# Leer el archivo csv y cargarlo en un dataframe
df = pd.read_csv("estaciones_metereologicas.csv")

# Mostrar las primeras filas del dataframe
df.head()

# Mostrar el número total de filas y columnas
print("Número de filas: ", len(df))
print("Número de columnas: ", len(df.columns))

# Calcular la media, desviación estándar, valor mínimo y valor máximo de la columna 'ALTURA'
altura_mean = df['ALTURA'].mean()
altura_std = df['ALTURA'].std()
altura_min = df['ALTURA'].min()
altura_max = df['ALTURA'].max()

print("Media de la altura: ", altura_mean)
print("Desviación estándar de la altura: ", altura_std)
print("Valor mínimo de la altura: ", altura_min)
print("Valor máximo de la altura: ", altura_max)

# %% [markdown]
# ## Ejercicio 2:
# Dados las siguientes estructuras:
#
# ```
# mi_lista = list('abcdefghijklmnopqrstuvwxyz')
#
# mi_array = np.arange(26)
#
# mi_diccionario = dict(zip(mi_lista,mi_array))
# ```
#
# 1. Crear una serie pandas para cada una de ellas, llamadas serLis, serArr y serDic.
# 2. Convertir la serie 'serDic' en un dataframe con su índice como otra columna en el dataframe.
# 3. Combine 'serLis' y 'serArr' para formar un dataframe.
# 4. Exporte el dataframe creado en el punto anterior a un archivo "serDic.csv" que quede grabado en la ruta: /content/drive/MyDrive/Colab Notebooks/Data/ (o en alguna equivalente si está trabajando en su propia computadora).

# %%
import pandas as pd
import numpy as np

mi_lista = list('abcdefghijklmnopqrstuvwxyz')
# Convierte la lista en una serie de pandas
serLis = pd.Series(mi_lista)

mi_array = np.arange(26)
# Convierte la lista en una serie de pandas
serArr = pd.Series(mi_array)

mi_diccionario = dict(zip(mi_lista, mi_array))
# Convierte la lista en una serie de pandas
serDic = pd.Series(mi_diccionario)

# Crea un dataframe a partir de la serie serDic, con el indice como una columna del dataframe
dfSerDic = pd.DataFrame({'letra': serDic.index, 'valor': serDic.values})

# Crea un dataframe a partir de las series serLis y serArr
df = pd.DataFrame({'letra': serLis, 'valor': serArr})

# Exporto el dataframe
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/serDic.csv', index=False)

# %% [markdown]
# ## Ejercicio 3:
#
# Un conjunto de datos (*dataset*) muy usado para ejercitar `Pandas` es el archivo [titanic.csv](https://drive.google.com/file/d/1edbySvT2KUDelJq85csEA6zxiOJ7TvXH/view?usp=share_link), que contiene información sobre los pasajeros del Titanic, con la descripción de las variables que se puede encontrar [aquí](https://drive.google.com/file/d/14ytgtHkAqbcpbUyWQZkNvw-ff7tisuXK/view?usp=share_link).
# Para este dataset hacer un programa que:
#
# 1. Carge los datos en un DataFrame y explorarlos
# 2. Muestre en pantalla las dimensiones, el número de datos que contiene y que muestre los tipos de datos de cada columna.
# 3. Muestre en pantalla los datos del pasajero con identificador 148.
# 4. Encuentre los nombres de las personas que iban en primera clase y los muestre ordenados alfabéticamente.
# 5. Elimine del DataFrame los pasajeros/as con edad desconocida.
# 6. Determine la edad media de las mujeres que viajaban en la clase 1.
# 7. Haga un histograma de la distribución de edades de los sobrevivientes sin distinguir el genero.

# %%
import pandas as pd

df = pd.read_csv("titanic.csv")

# Muestra informacion del DataFrame
df.info()
# Muestra las dimensiones, el número de datos 
print("Dimensiones del DataFrame:", df.shape)
print("Número total de datos:", df.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   IdPasajero     891 non-null    int64
#  1   Sobrevivencia  891 non-null    int64
#  2   Clase          891 non-null    int64
#  3   Nombre         891 non-null    object
#  4   Genero         891 non-null    object
#  5   Edad           714 non-null    float64
#  6   HerFam         891 non-null    int64
#  7   PadHi          891 non-null    int64
#  8   Ticket         891 non-null    object
#  9   Costo          891 non-null    float64
#  10  Cabina         204 non-null    object
#  11  Embarque       889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# Dimensiones del DataFrame: (891, 12)
# Número total de datos: 10692

# %%
df[ df["Clase"] == 2]
# Out:
#      IdPasajero  Sobrevivencia  Clase  \
# 9            10              1      2
# 15           16              1      2
# 17           18              1      2
# 20           21              0      2
# 21           22              1      2
# ..          ...            ...    ...
# 866         867              1      2
# 874         875              1      2
# 880         881              1      2
# 883         884              0      2
# 886         887              0      2
#
#                                            Nombre  Genero  Edad  HerFam  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0       1
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0       0
# 17                   Williams, Mr. Charles Eugene    male   NaN       0
# 20                           Fynney, Mr. Joseph J    male  35.0       0
# 21                          Beesley, Mr. Lawrence    male  34.0       0
# ..                                            ...     ...   ...     ...
# 866                  Duran y More, Miss. Asuncion  female  27.0       1
# 874         Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0       1
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0       0
# 883                 Banfield, Mr. Frederick James    male  28.0       0
# 886                         Montvila, Rev. Juozas    male  27.0       0
#
#      PadHi            Ticket    Costo Cabina Embarque
# 9        0            237736  30.0708    NaN        C
# 15       0            248706  16.0000    NaN        S
# 17       0            244373  13.0000    NaN        S
# 20       0            239865  26.0000    NaN        S
# 21       0            248698  13.0000    D56        S
# ..     ...               ...      ...    ...      ...
# 866      0     SC/PARIS 2149  13.8583    NaN        C
# 874      0         P/PP 3381  24.0000    NaN        C
# 880      1            230433  26.0000    NaN        S
# 883      0  C.A./SOTON 34068  10.5000    NaN        S
# 886      0            211536  13.0000    NaN        S
#
# [184 rows x 12 columns]

# %%
# Muestra los datos del pasajero con identificador 148:
print("Datos del pasajero con identificador 148:\n", df[df["IdPasajero"]==148])

# Otra forma:
df[df["IdPasajero"]==148]

# %%
# Encuentra los nombres de las personas que iban en primera clase y los muestra ordenados alfabéticamente
primera_clase = df[df['Clase'] == 1] #Filtro los datos apra quedarme con los pasajeros que estan el primera clase
nombres = primera_clase['Nombre'].sort_values() #Ordenados alfabéticamente

print("Nombres de las personas que iban en primera clase:\n", nombres)

# %%
# Elimina del DataFrame los pasajeros/as con edad desconocida
# El metodo .notna() busca los valores que no son nulos (not-null) en un Dataframe o Serie de pandas y devuelve un booleano con True (si no es nulo) o False (si es nulo).
df = df[df['Edad'].notna()]

# %%
# Determina la edad media de las mujeres que viajaban en la clase 1

mujeres_primera_clase = df[(df['Genero'] == 'female') & (df['Clase'] == 1)]

edad_media =mujeres_primera_clase['Edad'].mean()
print("Edad media de las mujeres que viajaban en primera clase:", edad_media)

# %%
# Hace un histograma de la distribución de edades de los sobrevivientes sin distinguir el género
sobrevivientes = df[df['Sobrevivencia'] == 1]
sobrevivientes['Edad'].plot.hist(bins=20)

# %% [markdown]
# ## Ejercicio 4:
#
# Vamos a trabajar con un nuevo dataset, el del archivo [`"Spotify 2010 - 2019 Top 100.csv"`](https://drive.google.com/file/d/18qHLJXvP16kmCfS6ZScAZnBxy1eAs63r/view?usp=sharing), extraído de [aquí](https://www.kaggle.com/datasets/muhmores/spotify-top-100-songs-of-20152019), que contiene información de las canciones más escuchadas cada año en la plataforma de streaming Spotify.
#
#
# 1. Explorar el dataset (mirar cuántos líneas hay, qué campos tiene, de que tipo son, etc.)
# 2. Mostrar los 10 artistas con más canciones a lo largo de todos los años y los 10 géneros más frecuentes.
# 3. Buscar cuáles son las canciones con tempos (*bpm*, pulsaciones por minuto) más elevados.
# (Sugerencia: investigar en la documentación de pandas sobre el método `sort_values()`)
# 4. Crear un nuevo DataFrame con los datos de ritmo (bpm) y duración (dur) promedio para cada año. (Sugerencia: es simple de hacerlo con el método `groupby()`)
# 5. A partir del DataFrame del inciso anterior, haga gráficos de la evolución de la duración y el ritmo promedio a lo largo de los años.
# 6. (Opcional) Investigue cómo hacer gráficos de torta en pandas y haga uno que muestre la proporción de los distintos tipos de artista ('artist type') de todo el dataset.

# %%
# 1) Leer el archivo csv y cargarlo en un dataframe
df_mus = pd.read_csv('/content/Spotify 2010 - 2019 Top 100.csv')

# %%
df_mus.head(10) #muestro las primeras 10 filas
# Out:
#                                            title           artist  \
# 0                  STARSTRUKK (feat. Katy Perry)            3OH!3
# 1                    My First Kiss (feat. Ke$ha)            3OH!3
# 2                                I Need A Dollar       Aloe Blacc
# 3  Airplanes (feat. Hayley Williams of Paramore)            B.o.B
# 4              Nothin' on You (feat. Bruno Mars)            B.o.B
# 5                     Magic (feat. Rivers Cuomo)            B.o.B
# 6                           The Time (Dirty Bit)  Black Eyed Peas
# 7                                        Imma Be  Black Eyed Peas
# 8                            Talking to the Moon       Bruno Mars
# 9                           Just the Way You Are       Bruno Mars
#
#      top genre  year released       added    bpm  nrgy  dnce   dB  live   val  \
# 0    dance pop         2009.0  2022‑02‑17  140.0  81.0  61.0 -6.0  23.0  23.0
# 1    dance pop         2010.0  2022‑02‑17  138.0  89.0  68.0 -4.0  36.0  83.0
# 2     pop soul         2010.0  2022‑02‑17   95.0  48.0  84.0 -7.0   9.0  96.0
# 3  atl hip hop         2010.0  2022‑02‑17   93.0  87.0  66.0 -4.0   4.0  38.0
# 4  atl hip hop         2010.0  2022‑02‑17  104.0  85.0  69.0 -6.0   9.0  74.0
# 5  atl hip hop         2010.0  2022‑02‑17   82.0  93.0  55.0 -4.0  35.0  79.0
# 6    dance pop         2010.0  2022‑02‑17  128.0  81.0  82.0 -8.0  60.0  44.0
# 7    dance pop         2009.0  2022‑02‑17   92.0  52.0  60.0 -7.0  31.0  41.0
# 8    dance pop         2010.0  2022‑02‑17  146.0  59.0  50.0 -5.0  11.0   8.0
# 9    dance pop         2010.0  2022‑02‑17  109.0  84.0  64.0 -5.0   6.0  42.0
#
#      dur  acous  spch   pop  top year artist type
# 0  203.0    0.0   6.0  70.0    2010.0         Duo
# 1  192.0    1.0   8.0  68.0    2010.0         Duo
# 2  243.0   20.0   3.0  72.0    2010.0        Solo
# 3  180.0   11.0  12.0  80.0    2010.0        Solo
# 4  268.0   39.0   5.0  79.0    2010.0        Solo
# 5  196.0    1.0  34.0  71.0    2010.0        Solo
# 6  308.0    7.0   7.0  75.0    2010.0  Band/Group
# 7  258.0   18.0  37.0  71.0    2010.0  Band/Group
# 8  218.0   51.0   3.0  87.0    2010.0        Solo
# 9  221.0    1.0   4.0  86.0    2010.0        Solo

# %%
df_mus.info() #Muestro informacion del dataset
# Mostrar el número total de filas y columnas
print("Número de filas: ", len(df_mus))
print("Número de columnas: ", len(df_mus.columns))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1000 non-null   object
#  1   artist         1000 non-null   object
#  2   top genre      1000 non-null   object
#  3   year released  1000 non-null   float64
#  4   added          1000 non-null   object
#  5   bpm            1000 non-null   float64
#  6   nrgy           1000 non-null   float64
#  7   dnce           1000 non-null   float64
#  8   dB             1000 non-null   float64
#  9   live           1000 non-null   float64
#  10  val            1000 non-null   float64
#  11  dur            1000 non-null   float64
#  12  acous          1000 non-null   float64
#  13  spch           1000 non-null   float64
#  14  pop            1000 non-null   float64
#  15  top year       1000 non-null   float64
#  16  artist type    1000 non-null   object
# dtypes: float64(12), object(5)
# memory usage: 133.3+ KB
# Número de filas:  1003
# Número de columnas:  17

# %%
# 2)
print(df_mus["artist"].value_counts()[0:10]) #Muestro la cantidad de veces que aparece cada artista y me quedo con los primeros 10
# Out:
# Taylor Swift     21
# Drake            18
# Calvin Harris    18
# Rihanna          14
# Ariana Grande    14
# Bruno Mars       13
# Maroon 5         11
# Post Malone      10
# Jason Derulo     10
# Ed Sheeran       10
# Name: artist, dtype: int64

# %%
print(df_mus['top genre'].value_counts()[0:10]) #Muestro la cantidad de veces que aparece cada genero musical y me quedo con los primeros 10
# Out:
# dance pop            361
# pop                   57
# atl hip hop           39
# art pop               37
# hip hop               21
# boy band              21
# canadian hip hop      18
# edm                   17
# folk-pop              15
# conscious hip hop     14
# Name: top genre, dtype: int64

# %%
# 3)Buscar cuáles son las canciones con tempos (*bpm*, pulsaciones por minuto) más elevados.
df_mus.sort_values(by='bpm', ascending=False)
# Out:
#                                                  title         artist  \
# 563                                    FourFiveSeconds        Rihanna
# 109                                          Honey Bee  Blake Shelton
# 898   BIG BANK (feat. 2 Chainz, Big Sean, Nicki Minaj)             YG
# 227                                          The Motto          Drake
# 969                            Pure Water (with Migos)        Mustard
# ...                                                ...            ...
# 38                                                Baby  Justin Bieber
# 896                                            changes   XXXTENTACION
# 1000                                               NaN            NaN
# 1001                                               NaN            NaN
# 1002                                               NaN            NaN
#
#                  top genre  year released       added    bpm  nrgy  dnce  \
# 563          barbadian pop         2015.0  2020‑06‑19  206.0  27.0  58.0
# 109   contemporary country         2011.0  2020‑06‑16  206.0  85.0  48.0
# 898               cali rap         2018.0  2020‑06‑22  204.0  35.0  75.0
# 227       canadian hip hop         2011.0  2020‑06‑22  202.0  44.0  77.0
# 969               cali rap         2019.0  2020‑06‑22  202.0  56.0  68.0
# ...                    ...            ...         ...    ...   ...   ...
# 38            canadian pop         2010.0  2022‑02‑17   65.0  86.0  73.0
# 896                emo rap         2018.0  2020‑06‑22   65.0  31.0  67.0
# 1000                   NaN            NaN         NaN    NaN   NaN   NaN
# 1001                   NaN            NaN         NaN    NaN   NaN   NaN
# 1002                   NaN            NaN         NaN    NaN   NaN   NaN
#
#         dB  live   val    dur  acous  spch   pop  top year artist type
# 563   -6.0  13.0  35.0  188.0   88.0   5.0  82.0    2015.0        Solo
# 109   -5.0  12.0  72.0  211.0    0.0   4.0  69.0    2011.0        Solo
# 898   -8.0   9.0  11.0  237.0    1.0  33.0  73.0    2018.0        Solo
# 227   -9.0  11.0  39.0  182.0    0.0  36.0  79.0    2012.0        Solo
# 969   -6.0  34.0  14.0  192.0   17.0  13.0  80.0    2019.0        Solo
# ...    ...   ...   ...    ...    ...   ...   ...       ...         ...
# 38    -5.0  11.0  54.0  214.0    4.0  14.0  86.0    2010.0        Solo
# 896  -10.0  10.0  52.0  122.0   88.0   3.0  84.0    2018.0        Solo
# 1000   NaN   NaN   NaN    NaN    NaN   NaN   NaN       NaN         NaN
# 1001   NaN   NaN   NaN    NaN    NaN   NaN   NaN       NaN         NaN
# 1002   NaN   NaN   NaN    NaN    NaN   NaN   NaN       NaN         NaN
#
# [1003 rows x 17 columns]

# %%
# 4)Crear un nuevo DataFrame con los datos de ritmo (bpm) y duración (dur) promedio para cada año. 
a = df_mus.groupby('top year').mean() #con .grupby() agrupo el dataset por año ([columna "top year"]) y luego calculo el valor medio de cada grupo.
df = pd.DataFrame({'bpm': a["bpm"], 'dur': a["dur"]}) #creo el dataset con las dos columnas: bpm y dur
df
# Out:
# <ipython-input-15-852b08bd148a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a = df_mus.groupby('top year').mean() #con .grupby() agrupo el dataset por año ([columna "top year"]) y luego calculo el valor medio de cada grupo.
#              bpm     dur
# top year
# 2010.0    119.56  226.45
# 2011.0    127.29  230.19
# 2012.0    123.10  226.38
# 2013.0    119.91  229.49
# 2014.0    119.73  227.90
# 2015.0    120.86  218.46
# 2016.0    115.77  219.86
# 2017.0    122.02  221.04
# 2018.0    120.55  208.79
# 2019.0    123.83  195.50

# %%
# 5)gráficos de la evolución de la duración y el ritmo promedio a lo largo de los años
a.plot.line(y='bpm')
a.plot.line(y='dur')
# Out:
# <Axes: xlabel='top year'>

# %%
# 6)Grafico de torta para la proporción de los distintos tipos de artista ('artist type') de todo el dataset.
df_mus['artist type'].value_counts().plot.pie(autopct='%1.0f%%')
# Out:
# <Axes: ylabel='artist type'>

# %% [markdown]
# ## Ejercicio 5:
#
# Esta vez vamos a trabajar con los datos de los casos confirmados de Covid en la provincia de Santa Fe, que están en el archivo [`'casos_covid_confirmados_santafe.csv'`](https://drive.google.com/file/d/1DvshOSsVU34KdhCe1k85wyi-KVI9g6QS/view?usp=sharing). Los mismos fueron obtenidos reduciendo el dataset oficial de los casos de covid en todo el país. *(Advertencia: el archivo pesa unos 85 MB)*
#
# 1. Cargue los contenidos del csv en un DataFrame de Pandas y explore el dataset. En particular, pedimos reportar cuántos registros contiene y qué columnas tiene. ¿Cuáles son todos los valores posibles de la columna `"clasificacion"`?
# 2. Calcular cuánta gente de Santa Fe falleció por covid. ¿Qué porcentaje de los casos totales terminaron en muertes (o sea, cuál es la mortalidad)?
# 3. Calcule cuántos casos y muertes hubo en cada departamento de la provincia de Santa Fe.
# 4. Haga un histograma de edades de los casos confirmados. Ojo, hay que descartar primero los que tienen la edad contada en meses (mire la columna `"edad_años_meses"`). Haga también un segundo histograma de edades solo de los fallecidos. *(Sí, en el dataset hay alguien que figura que tiene 222 años... esos errores pasan. Se puede intentar filtrar esos casos para que no molesten en el histograma.)*
# 5. Haga el gráfico de casos diarios de covid. Para eso utilizá la columna `"fecha_apertura"`.

# %%
# 1)Cargo el dataset
import pandas as pd

df_covid = pd.read_csv("/content/casos_covid_confirmados_santafe.csv")
df_covid.head()
# Out:
#    id_evento_caso sexo  edad edad_años_meses residencia_departamento_nombre  \
# 0        10000072    F  38.0            Años                    San Lorenzo
# 1        10000269    F  35.0            Años                        Rosario
# 2        10000345    M  23.0            Años                  General López
# 3        10000379    M  35.0            Años                    San Lorenzo
# 4        10000793    F  34.0            Años                        Rosario
#
#   fecha_apertura cuidado_intensivo fallecido fecha_fallecimiento  \
# 0     2021-04-08                NO        NO                 NaN
# 1     2021-04-08                NO        NO                 NaN
# 2     2021-04-08                NO        NO                 NaN
# 3     2021-04-08                NO        NO                 NaN
# 4     2021-04-08                NO        NO                 NaN
#
#                                        clasificacion
# 0  Caso confirmado por laboratorio - No activo (p...
# 1  Caso confirmado por laboratorio - No activo (p...
# 2  Caso confirmado por laboratorio - No activo (p...
# 3  Caso confirmado por laboratorio - No activo (p...
# 4  Caso confirmado por laboratorio - No Activo po...

# %%
# Mostrar el número total de filas y columnas
print("Número de filas: ", len(df_covid ))
print("Número de columnas: ", len(df_covid .columns))
# Out:
# Número de filas:  34655
# Número de columnas:  10

# %%
# Mostrar que valores toma la columna "clasificacion"
print(df_covid.clasificacion.unique())
# Out:
# ['Caso confirmado por laboratorio - No activo (por tiempo de evolución)'
#  'Caso confirmado por laboratorio - No Activo por criterio de laboratorio'
#  'Caso confirmado por laboratorio - Fallecido'
#  'Caso confirmado por criterio clínico-epidemiológico - No activo (por tiempo de evolución)'
#  'Caso confirmado por criterio clínico-epidemiologico - Fallecido'
#  'Caso confirmado por criterio clínico - epidemiológico -  Activo internado']

# %%
# 2)Calcular cuánta gente de Santa Fe falleció por covid.
fallecidos = df_covid.fallecido.value_counts() #Valores de la columna fallecidos
print(fallecidos)

100*fallecidos.loc['SI']/(fallecidos.loc['SI']+fallecidos.loc['NO']) #porcentaje que terminaron en muertes.
# Out:
# NO    34027
# SI      628
# Name: fallecido, dtype: int64
# 1.8121483191458665

# %%
# 3)Calcule cuántos casos y muertes hubo en cada departamento de la provincia de Santa Fe.
df_departamento=df_covid.groupby("residencia_departamento_nombre")["fallecido"] #agrupo por departamento y me quedo con la columna "fallecido"
df_departamento.value_counts() #muestro el conteo de valores de fallecidos
# Out:
# residencia_departamento_nombre  fallecido
# 9 de Julio                      NO             213
#                                 SI               5
# Belgrano                        NO             542
#                                 SI               4
# Caseros                         NO             666
#                                 SI              18
# Castellanos                     NO            3110
#                                 SI              64
# Constitución                    NO             859
#                                 SI              15
# Garay                           NO             128
#                                 SI               1
# General López                   NO            1185
#                                 SI              37
# General Obligado                NO             460
#                                 SI              12
# Iriondo                         NO            1002
#                                 SI               8
# La Capital                      NO            4663
#                                 SI              85
# Las Colonias                    NO            1125
#                                 SI              20
# Rosario                         NO           14626
#                                 SI             263
# San Cristóbal                   NO            1506
#                                 SI              42
# San Javier                      NO              72
#                                 SI               1
# San Jerónimo                    NO             660
#                                 SI              15
# San Justo                       NO             578
#                                 SI               4
# San Lorenzo                     NO            1740
#                                 SI              12
# San Martín                      NO             779
#                                 SI              21
# Vera                            NO             113
#                                 SI               1
# Name: fallecido, dtype: int64

# %%
# d)
# todos los confirmados
df_covid[(df_covid.edad_años_meses=='Años') & (df_covid.edad<101)].hist(column="edad", bins=20)

# solo fallecidos
df_covid[(df_covid.edad_años_meses=='Años') & (df_covid.edad<101) & (df_covid.fallecido=='SI')].hist(column="edad", bins=20)

# %%
# 5) gráfico de casos diarios de covid
df_covid['fecha_apertura'] = pd.to_datetime(df_covid['fecha_apertura'], format= '%Y-%m-%d')
df_covid_fechas = df_covid['fecha_apertura'].value_counts().sort_index()
#df_covid.plot.hist(columns="fecha_apertura")
df_covid_fechas.plot.line(figsize=(18,8), grid=True)

# %%
import numpy as np
a = [[4,5,6,73,6],[2,4,5,6,3]]
a.sort(axe=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2e9cc228d4be> in <cell line: 3>()
#       1 import numpy as np
#       2 a = [[4,5,6,73,6],[2,4,5,6,3]]
# ----> 3 a.sort(axe=0)
#
# TypeError: 'axe' is an invalid keyword argument for sort()
