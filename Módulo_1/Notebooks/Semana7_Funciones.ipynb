# %% [markdown]
# # Semana 7: Funciones
# Miércoles 29 de Marzo

# %% [markdown]
# ## Recapitulación
#
# En el notebook de la Semana 5 definimos una **función** como un bloque de código que realiza una tarea específica y que se puede reutilizar en diferentes partes de un programa. Las funciones son una herramienta muy poderosa en Python, ya que nos permiten agrupar un conjunto de instrucciones relacionadas en un solo lugar, lo que hace que nuestro código sea más modular, más fácil de entender y más fácil de mantener.
#
# También mostramos que ya usamos varias funciones de manera natural e intuitiva como en este ejemplo donde llamamos a las funciones `range()` y `print()`.

# %%
# Armado de lista de números del 1 al 10:
numeros = []

for i in range(10):
  numeros.append(i+1)

print(numeros)

# %% [markdown]
# También aprendimos a usar módulos usando `import` y a llamar las funciones de esos módulos, como por ejemplo:

# %%
import math
x = math.sqrt(10)
print(x)

# %% [markdown]
# ## Definición

# %% [markdown]
# Este tipos de funciones son de Python o de Módulos de Python que podemos importar, pero también podemos hacer *nuestras propias funciones*. Para eso vamos usar la palabra clave `def`, seguida del nombre de la función y los argumentos que recibe.
#
# Como por ejemplo, la siguiente función imprime el mensaje "¡Hola, mundo!" cuando se llama:

# %%
def hola_mundo():
    print("¡Hola mundo!")

# %% [markdown]
# Para llamar a la función, simplemente escribe su nombre seguido de paréntesis:

# %%
hola_mundo()

# %% [markdown]
# Como podemos ver la función es simple e imprime en pantalla lo esperado. Esta función no tiene ningún argumento.

# %% [markdown]
# Las funciones también pueden tener argumentos, que son parámetros o valores que debemos pasan a la función cuando son llamas. Los argumentos se definen entre paréntesis después del nombre de la función.
#
# Por ejemplo, la siguiente función toma un parámetro llamado "nombre" y lo utiliza para imprimir un saludo personalizado:

# %%
def saludar(nombre):
    print("¡Hola, " + nombre + "!")

# %% [markdown]
# Para llamar a esta función, se debe proporcionar un valor para el parámetro "nombre":

# %%
saludar("Juan")
# Out:
# ¡Hola, Juan!

# %% [markdown]
# Además, las funciones en Python pueden devolver un valor usando la palabra clave "return". El valor devuelto puede ser utilizado por el programa que llama a la función. Por ejemplo, la siguiente función toma dos parámetros y devuelve su suma:

# %%
def sumar(a, b):
    return a + b

# %% [markdown]
# Para utilizar el valor devuelto por la función, se debe asignar el resultado a una variable:

# %%
resultado = sumar(2, 3)
print(resultado)

# %% [markdown]
# ## Estructura de una función

# %% [markdown]
# Por lo que vimos podemos decir que una función contiene:
# * nombre de la función
# * argumentos
# * código de la función
# * valor (o valores) de retorno
#
# Además para que la función trabaje debe ser invocada. Esto lo podemos resumir en lo siguiente:
#
# ![ EstructuraFuncion.png](data:image/png;base64,...)

# %% [markdown]
# ### Funciones sin argumentos
#
# Como vimos anteriormente en el primer ejemplo, una función que no recibe ningún valor de entrada se dice que no tiene argumentos. Si bien es un poco extraño, hay varias razones por las cuales queremos usarlas:
#
# 1. Para realizar una acción específica, como imprimir un mensaje o realizar un cálculo predefinido. Como en el ejemplo anterior de `¡Hola mundo!`.
# 2. Si esta usa variables globales, o sean que están definidas en el ambito global de una función y entonces no hay necesidad de pasar variables a la función.

# %%
def duplicar():
  global numero

  numero=8
  numero = numero * 2

# %%
print(numero)
# Out:
# 2

# %% [markdown]
# 3. Como un marcador de posición, cuando necesitamos definir una función que se llamará en el futuro, pero que por ahora no la usaremos o no sobremos bien que argumentos vamos a necesitar.

# %%
def funcion_a_definir():
  # Código que se definirá más adelante
  pass

# %% [markdown]
# ### Paso de argumentos por posición
#
# En el caso de que una función tenga parámetros, los pasamos de acuerdo al orden en que aparecen. Veamos el siguiente ejemplo:

# %%
# defino la punción potencia
def pot(valor, potencia):
  resultado = valor**potencia
  return resultado

# queremos calcular la potencia 3 de 5:
print(pot(5,3))

# %% [markdown]
# El orden importa, porque no es lo mismo que calcular la potencia 5 de 3:

# %%
print(pot(3,5))

# %% [markdown]
# Entonces es importante colocar correctamente el orden de los parámetros

# %% [markdown]
# ### Paso de argumentos por nombre
#
# En Python no necesitamos escribir los argumentos en el orden en que están definidos en la función siempre y cuando estemos especificando el parámetro que le estamos pasando. Volvamos a la función que calcula la potencia:

# %%
print(pot(potencia=3,valor=5))

# %% [markdown]
# ### Argumentos *por default*
#
# En Python también podemos especificar argumentos *por default* (por defecto), de modo que aunque no se pase el valor correspondiente de ese argumento, la función asume uno *por default*.

# %%
def raiz(valor, indice=2):
  resultado = valor**(1/indice)
  return resultado

raiz3 = raiz(27,3)
raiz2 = raiz(25)
print(raiz3, raiz2)

# %% [markdown]
# Atención: Necesitamos definirlo en la función, sino da error! Veamos el ejemplo anterior, cuando calculabamos la potencia.

# %%
print(pot(3))

# %% [markdown]
# ### Argumentos indeterminados
#
# Una función puede usar parámetros indererminados, para eso, en Python, usamos la expresión `*args`. Por ejemplo:

# %%
def sumar(*args):
  resultado = 0
  for valor in args:
      resultado = resultado + valor  
  return resultado

total = sumar(4, 2, 6, 9)
print(total)

# %%
print(sumar(1,2))

# %%
print(sumar(4,7,14,3,2,8,5,7))

# %% [markdown]
# Aquí la función identifica a los argumentos por la posición que ellos ocupan `args` (que viene de 'arguments' en ingles que significa argumentos o valores) es una tupla.
#
# Pero también podemos identificarlos por nombre (clave-valor o en inglés 'keyword args') usando el comando `kwargs`. Por ejemplo:

# %%
def indeterminados_nombre(**kwargs):
    print(kwargs)
    print(type(kwargs))

indeterminados_nombre(n=5, c="Hola", l=[1,2,3,4,5])
# Out:
# {'n': 5, 'c': 'Hola', 'l': [1, 2, 3, 4, 5]}
# <class 'dict'>

# %% [markdown]
# Aquí kwargs es un diccionario, y por ejemplo podriamos tener una función que itere sobre las llaves e imprima el valor de la siguiente forma:

# %%
def func(**kwargs):
    for kwarg in kwargs:
        print(kwarg, "=>", kwargs[kwarg])

func(n=4, c='Hola mundo', a = [2,4,6])

# %% [markdown]
# ### Ejercicio 1
#
# Realiza una función llamada `intermedio(a, b)` que a partir de dos números, devuelva su punto intermedio. Cuando la tengas comprueba que el punto intermedio entre -12 y 24 es 6.
#
# *Nota:El número intermedio de dos números corresponde a la suma de los dos números dividida entre 2*

# %%
def intermedio(a, b):
  

intermedio(-12, 24)

# %% [markdown]
# ### Ejercicio 2
# Definir una función que permita sumar los `n` primeros números enteros. Probar la función para diferente valores.

# %%
def sumacontador(n):
  

sumacontador(10)

# %%
def sumacontador(n):
  total=0

  while n>0:
    total+=n
    n-=1
    
  return total


sumacontador(2)
# Out:
# 3

# %%
def sumar_enteros(n):
    suma = 0
    i = 1
    while i <= n:
        suma += i
        i += 1
    return suma

# %% [markdown]
# ## Más sobre funciones

# %% [markdown]
# ### Retorno de múltiples valores
#
# Hasta ahora vimos funciones que hacian algo o que nos retornaban un único valor. Pero en Python podemos devolver múltiples valores.
#
# Veamos el siguiente ejemplo:

# %%
def CuadradoCubo(n):
  cuadrado = n ** 2
  cubo = n ** 3
  return cuadrado, cubo

a = CuadradoCubo(5)
print(a,type(a))

# %% [markdown]
# Como vemos, nos devuelve una `tupla` de valores.  Podemos desempaquetar la `tupla` haciendo:

# %%
c2, c3 = CuadradoCubo(5)
print(c2)
print(c3)

# %% [markdown]
# ### Función recursiva
#
# Las funciones recursivas son aquellas que se llaman a sí mismas dentro de su propia definición. En Python, se pueden utilizar para resolver problemas que se pueden dividir en problemas más pequeños del mismo tipo.

# %% [markdown]
# Por ejemplo, supongamos que queremos calcular el factorial de un número entero. El factorial de un número es el producto de todos los números enteros desde 1 hasta ese número.
#
# El factorial de 3 lo escribimos así: 3! = 3 \* 2 \* 1 = 6
#
# Entonces, 4! = 4 \* 3 \* 2 \* 1
#
# Y 5! = 5 \* 4 \* 3 \* 2 \* 1
#
# Queremos una función que calcule el factorial de n, eso es: n! = n \* (n-1) \* (n-2) \* ...  \* 1
#
# *Nota: 0! = 1*

# %% [markdown]
# Podemos escribir una función recursiva para calcular el factorial de la siguiente manera:

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        print(n)
        return n * factorial(n-1)

# %%
factorial(3)
# Out:
# 3
# 2
# 1
# 6

# %% [markdown]
# El primer llamado a la función es `factorial(5)`. Como `5` no es igual a `0`, la función devuelve `5 * factorial(4)`. El siguiente llamado a la función es `factorial(4)`. De nuevo, como `4` no es igual a `0`, la función devuelve `4 * factorial(3)`. Este proceso continúa hasta que la función `factorial(1)` se llama, en cuyo caso devuelve `1`. Luego, las funciones se devuelven en orden inverso, de modo que `factorial(2)` devuelve `2 * 1 = 2`, `factorial(3)` devuelve `3 * 2 = 6`, `factorial(4)` devuelve `4 * 6 = 24`, y finalmente `factorial(5)` devuelve `5 * 24 = 120`.

# %% [markdown]
# * Ventajas de la recursividad:
# > * Las funciones recursivas hacen que el código se vea limpio y elegante
# > * Una tarea compleja se puede dividir en subproblemas más simples mediante la recursividad.
# > * La generación de secuencias es más fácil con la recursivad que con algunas interaciones anidadas.
#
# * Desventajas de la recursividad:
# > * Algunas veces la lógica detrás de la recursividad es más dificil de seguir.
# > * Las llamadas recursivas pueden ser ineficaces en lo que respecta a memoria y tiempo de ejecución.
# > * Dependiendo de la complejidad, las funciones recursivas pueden ser mas difíciles de debuggear.

# %% [markdown]
# ### Funciones anidadas o funciones internas
#
# La definición de una función dentro de otra función es útil en situaciones en las que una función necesita utilizar una función auxiliar que sólo se utiliza dentro de la función principal. En lugar de definir la función auxiliar fuera de la función principal y hacer que esté disponible en todo el programa, podemos definirla dentro de la función principal para limitar su alcance.

# %% [markdown]
# Por ejemplo queremos una función que calcule la suma de los cuadros de los números de una lista, sin usar NumPy.

# %%
def calcular_suma_cuadrados(lista):
    def cuadrado(numero):
        return numero ** 2

    suma = 0
    for num in lista:
        suma += cuadrado(num)
    return suma

# %%
# Ejemplo de uso
lista = [1, 2, 3, 4, 5]
resultado = calcular_suma_cuadrados(lista)
print(resultado)

# %% [markdown]
# En este ejemplo, la función `calcular_suma_cuadrados` define una función anidada llamada `cuadrado`. Esta función interna toma un número y devuelve su cuadrado. La función principal `calcular_suma_cuadrados` utiliza la función `cuadrado` para calcular la suma de los cuadrados de los elementos de una lista. En este caso, la lista es `[1, 2, 3, 4, 5]`, por lo que la función `calcular_suma_cuadrados` devuelve la suma de los cuadrados de estos números, que es `1 + 4 + 9 + 16 + 25 = 55`.
#
# Es importante tener en cuenta que la función interna `cuadrado` sólo es visible dentro de la función principal `calcular_suma_cuadrados`. No se puede acceder a ella desde fuera de la función. Esto significa que la función `cuadrado` no interfiere con otras partes del programa y sólo se utiliza cuando se llama a `calcular_suma_cuadrados`.

# %% [markdown]
# ### Ejercicio 3
#
# Escribir la función del Ejercicio 1 en forma recursiva, para que sume los `n` primeros números enteros.

# %%
def sumarecursiva(n):
  if n == 0:
    return 0
  else:
    return n + sumarecursiva(n-1)

sumarecursiva(3)
# Out:
# 6

# %% [markdown]
# ## Algunos comentarios
#
# * Recordar que si la función incluye parámetros, debemos proporcionar el mismo número de parámetros cuando llame a la función.

# %%
def multiplica(a,b):
  return a*b

# %%
print(multiplica(3))        # TypeError: multiplica() tiene 1 parametro perdido, falta 'b'

# %% [markdown]
# * Qué obtenemos si hacemos:

# %%
print(multiplica('a',5))
#print(multiplica('a','b'))

# %% [markdown]
# * El bloque de código que ejecutará la función incluye todas las declaraciones con identación dentro de la función. Por ejemplo:

# %%
def miFuncion():
  print('Aqui estamos imprimiendo algo')
  print('Podemos imprimir lo que querramos')

x = 7
# la asignación de x no es parte de la función ya que no está identada

# %%
miFuncion()

# %% [markdown]
# * Si no se define un resultado, o si falta el comando return, la función devuelve la constante `None`.

# %%
a = miFuncion()
print(a)

# %% [markdown]
# > Lo mismo ocurre si no colocamos nada en el `return` de la función:

# %%
def no_hace_nada(a, b):
  a + b
  return

print(no_hace_nada(1, 2))

# %% [markdown]
# * Las variables (¡y funciones!) definidas dentro de una función solo existen dentro de ámbito de esa función.

# %%
def duplica(num):
  y = num * 2
  return y

print(y)                    # error - y no está definida
print(duplica(4))           # muestra el valor 8

# %% [markdown]
# * La función termina al llegar a un `return`, devolviendo los valores correspondientes. Si hay código después de ello, ¡no se va a ejecutar!

# %%
def sumar(a, b):
  s = a + b
  return s
  print('La suma es', s)

sumar(2,2)

# %% [markdown]
# > Esto es particularmente relevante en el caso de la función tenga varios `return`s:

# %%
def buscar_pos(lista, a):
  '''Busca la posición de a en la lista. Si no está devulve None'''
  for i, e in enumerate(lista):
    if e == a:
      return i
  return

print(buscar_pos([1, 6, 3, 4, 3], 3)) # ¡Sólo devulve la primera posición!
print(buscar_pos([1, 6, 3, 4, 3], 7))

# %% [markdown]
# ### Ejercicio 4
# (era el ejercicio opcional en la Semana 3)
#
# Supongamos que tenemos una lista de números enteros, y queremos encontrar todas las subsecuencias de la lista que sumen un número objetivo dado. Para hacerlo, vamos a crear una función que tome como argumentos la lista de números y el número objetivo, y devuelva una lista con todas las subsecuencias que suman el número objetivo.
#
# Ayuda: Por ejemplo, si le damos a tu programa la lista de números [1, 2, 3, 4, 5] y queremos encontrar todas las subsecuencias que suman 7 (número objetivo dado), la función debería devolver las siguientes listas [2, 5], [3, 4], [1, 2, 4].

# %%
def subsecuencias_suma(lista, objetivo):
    def backtrack(inicio, sumaval, subsecuencia_actual):
        if sumaval == objetivo:
            res.append(subsecuencia_actual)
            return
        for i in range(inicio, len(lista)):
            if sumaval + lista[i] <= objetivo:
                backtrack(i+1, sumaval+lista[i], subsecuencia_actual+[lista[i]])

    res = []
    backtrack(0, 0, [])
    return res

# %%
lista = [1, 2, 3, 4, 5]
objetivo = 7
resultados = subsecuencias_suma(lista, objetivo)
print(resultados)

# %% [markdown]
# ## Información complementaria, no es necesario saber.

# %% [markdown]
# ### Errores y excepciones
#
# Las funciones informan los errores como excepciones. Dado que una excepción interrumpe la ejecución de una función, la misma puede generar que todo el programa se detenga si no es administrada adecuadamente.

# %%
int('N/A')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-9c845d7aae51> in <module>
# ----> 1 int('N/A')
#
# ValueError: invalid literal for int() with base 10: 'N/A'

# %% [markdown]
# Para poder entender qué pasó (debuguear), el mensaje describe cuál fue el problema, dónde ocurrió y un poco de la historia (*traceback*) de los llamados que terminaron en este error.

# %% [markdown]
# ### Atrapar y administrar excepciones
#
# Las excepciones pueden ser atrapadas y administradas. Para atrapar una excepción, se usan los comandos `try` - `except`.

# %%
numero_valido=False
while not numero_valido:
    try:
        a = input('Ingresá un número entero: ')
        n = int(a)
        numero_valido = True
    except ValueError:
        print('No es válido. Intentá de nuevo.')
print(f'Ingresaste {n}.')

# %% [markdown]
# Si en este ejemplo ingresas por ejemplo una letra, el comando `n = int(a)` genera una excepción de tipo ValueError: el comando `numero_valido = True` no se ejecuta, la excepción es atrapada por el except `ValueError` y el ciclo se repite. Probalo ingresando letras, números con decimales y números enteros.
#
# Suele ser difícil saber exactamente qué tipo de errores pueden ocurrir por adelantado. Para bien o para mal, la administración de excepciones suele ir creciendo a medida que un programa va generando errores inesperados (al mejor estilo: "Uh! Me olvidé de que podía pasar esto. Deberíamos preverlo y administrarlo adecuadamente para la próxima").

# %% [markdown]
# ### Generar excepciones
#
# Para generar una excepción (también diremos levantar una excepción, porque más cercano al término inglés "raise"), se usa el comando `raise`.

# %%
raise RuntimeError('Algo salió mal!')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-87c370e3d341> in <module>
# ----> 1 raise RuntimeError('Algo salió mal!')
#
# RuntimeError: Algo salió mal!

# %% [markdown]
# ## Extra

# %% [markdown]
# ### Resolución del ejercicio 4 con prints para entender lo que hace:

# %%
def subsecuencias_suma(lista, objetivo):
    def backtrack(inicio, sumaval, subsecuencia_actual):
        print('empieza func: inicio =',inicio, "suma valores =", sumaval, subsecuencia_actual)
        if sumaval == objetivo:
            res.append(subsecuencia_actual)
            print('cumple objetivo!',res)
            return
        print(' ------------------------------------------------ antes del for:',inicio, len(lista),subsecuencia_actual)
        for i in range(inicio, len(lista)):
            print('dentro for: i =',i, 'range(',inicio, len(lista),')', sumaval + lista[i])
            if sumaval + lista[i] <= objetivo:
                print(' dentro if:',i+1, sumaval+lista[i], subsecuencia_actual+[lista[i]])
                backtrack(i+1, sumaval+lista[i], subsecuencia_actual+[lista[i]])

    res = []
    backtrack(0, 0, [])
    return res

# %%
lista = [1, 2, 3, 4, 5]
objetivo = 7
resultados = subsecuencias_suma(lista, objetivo)
print(resultados)
# Out:
# empieza func: inicio = 0 suma valores = 0 []
#  ------------------------------------------------ antes del for: 0 5 []
# dentro for: i = 0 range( 0 5 ) 1
#  dentro if: 1 1 [1]
# empieza func: inicio = 1 suma valores = 1 [1]
#  ------------------------------------------------ antes del for: 1 5 [1]
# dentro for: i = 1 range( 1 5 ) 3
#  dentro if: 2 3 [1, 2]
# empieza func: inicio = 2 suma valores = 3 [1, 2]
#  ------------------------------------------------ antes del for: 2 5 [1, 2]
# dentro for: i = 2 range( 2 5 ) 6
#  dentro if: 3 6 [1, 2, 3]
# empieza func: inicio = 3 suma valores = 6 [1, 2, 3]
#  ------------------------------------------------ antes del for: 3 5 [1, 2, 3]
# dentro for: i = 3 range( 3 5 ) 10
# dentro for: i = 4 range( 3 5 ) 11
# dentro for: i = 3 range( 2 5 ) 7
#  dentro if: 4 7 [1, 2, 4]
# empieza func: inicio = 4 suma valores = 7 [1, 2, 4]
# cumple objetivo! [[1, 2, 4]]
# dentro for: i = 4 range( 2 5 ) 8
# dentro for: i = 2 range( 1 5 ) 4
# ...
