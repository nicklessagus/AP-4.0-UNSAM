# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
tf.keras.backend.clear_session()

# %% [markdown]
# # Uso de AutoEncoders para detectar anomalías.

# %% [markdown]
# Una de las aplicacciones de los autoencoders es la **detección de anomalías / errores**; es decir, datos que no pertenecen a la misma distribución que el conjunto de entrenamiento.
#
# Hay dos maneras, principalmente, de evaluar cuán lejos está un punto del conjunto del dataset de entrenamiento usando autoencoders:
#
# 1. comparar el error de reconstrucción
# 2. comparar la posición de la codificación en el espacio latente.
#
# Vamos a retomar el dataset de las tarjetas de crédito para evaluar la capacidade los autoenconders para detectar las transacciones fraudulentas.

# %% [markdown]
# ## Obtención de los datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# X_train = pd.read_csv('../../datasets/creditcard/creditcard_train.csv')
X_train = pd.read_csv('/content/drive/MyDrive/creditcard_train.csv')
# X_test = pd.read_csv('../../datasets/creditcard/creditcard_test.csv')
X_test = pd.read_csv('/content/drive/MyDrive/creditcard_test.csv')

# %% [markdown]
# Veamos rápidamente los datos.

# %%
X_train.head()
# Out:
#    Unnamed: 0        V1        V2        V3        V4        V5        V6  \
# 0       20851  1.321432 -0.356293  0.300205  0.201982 -0.208365  0.743361
# 1      155337 -0.605459  0.917276  2.369555 -0.139944  0.140190 -0.259833
# 2      111001  1.279970 -0.266108 -0.992069 -0.285321  1.883019  3.657542
# 3       86746 -1.544809 -1.552024  1.691270 -2.704450 -0.754460 -1.160318
# 4      193607 -1.160451 -0.684065  1.339608 -2.474749  0.044282  1.807347
#
#          V7        V8        V9  ...       V19       V20       V21       V22  \
# 0 -0.656105  0.070828 -0.881980  ... -1.232635 -0.388459 -0.281173 -0.243962
# 1  0.522574 -0.295835  1.562154  ...  0.472211  0.036851 -0.287622 -0.399948
# 2 -0.715670  0.900671  0.496412  ...  0.559915 -0.003480 -0.142442 -0.316956
# 3  0.418050 -0.146795 -0.211499  ... -0.384878  0.321047 -0.118830 -0.358626
# 4  0.662735  0.499480 -1.291674  ... -0.224986  0.483143  0.014931 -0.349837
#
#         V23       V24       V25       V26       V27       V28
# 0 -0.163223 -1.324377  0.537850 -0.189712  0.088370  0.026635
# 1 -0.306285 -0.112976  0.239806 -0.738243 -0.212029 -0.143259
# 2 -0.123535  1.063070  0.742956  0.453687 -0.014068  0.004009
# 3  0.406065  0.396461  0.596016 -0.081761 -0.039167  0.099800
# 4  0.293706 -1.686113  0.339169 -0.429552 -0.013272  0.042696
#
# [5 rows x 29 columns]

# %%
X_test.head()
# Out:
#    Unnamed: 0        V1        V2        V3        V4        V5        V6  \
# 0      202371  2.138046  0.090194 -2.449974  0.522469  0.578042 -1.794888
# 1      204691 -0.248224  0.728713 -0.582032 -0.676084  1.339694 -0.418703
# 2      256660  2.134145 -0.661134 -1.620203 -1.809978 -0.493491 -1.650889
# 3       87120 -1.247223  1.473491  2.358967  0.452132 -0.283562 -0.090984
# 4       85534  1.052610 -0.161350  0.190391  1.259294 -0.172069  0.297286
#
#          V7        V8        V9  ...       V19       V20       V21       V22  \
# 0  0.913447 -0.570769  0.142075  ...  0.067419 -0.363305  0.239569  0.782559
# 1  0.820419  0.002756 -0.252639  ...  0.221051  0.006054 -0.313248 -0.729786
# 2  0.049240 -0.394478  2.479669  ...  1.286566 -0.301007  0.169722  0.935373
# 3  0.754620 -0.489365  0.723121  ...  0.446239  0.712766 -0.200742  0.041708
# 4 -0.129089  0.266126  0.382070  ...  0.045509 -0.214113 -0.068596 -0.209817
#
#         V23       V24       V25       V26       V27       V28
# 0 -0.183510 -0.059540  0.634883  0.735714 -0.137668 -0.097352
# 1  0.311922  0.181350 -0.334001  0.114217  0.125575  0.037668
# 2 -0.103471  0.033117  0.550642 -0.551365  0.032345 -0.064503
# 3 -0.244385  0.480266  0.249295 -0.496836 -0.302590 -0.436892
# 4 -0.129953 -0.345397  0.585089 -0.307521  0.012335  0.005977
#
# [5 rows x 29 columns]

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (50000, 29)
# (57355, 29)

# %% [markdown]
# Eliminamos la primera columna, que es el identificador de la transacción

# %%
X_train.drop(['Unnamed: 0',], axis=1, inplace=True)

# %%
# Para el test, guardamos la info para comparar
id_test = X_test['Unnamed: 0']
X_test.drop(['Unnamed: 0',], axis=1, inplace=True)

# %% [markdown]
# Recobremos, además, las etiquetas a partir de un archivo que tiene los índices de las transacciones fraudulentas.

# %%
# Ahora recobremos los valores reales
#id_fraudes = np.loadtxt('../../datasets/creditcard/credit_fraud.txt')
id_fraudes = np.loadtxt('/content/sample_data/credit_fraud.txt')

t_test = id_test.isin(id_fraudes)

# %% [markdown]
# ## Construcción del modelo

# %%
# tamano de la representación interna.
encoding_dim = 5  # 32 flotantes -> un factor de compresión de 24.5

#input placeholder
input_layer = keras.layers.Input(shape=(28,))

# %%
### Primero el encoder
#
encoded = keras.layers.Dense(16, activation='relu')(input_layer)
encoded = keras.layers.Dense(8, activation='relu')(encoded)
encoded = keras.layers.Dense(encoding_dim, activation='tanh')(encoded)

encoder = keras.models.Model(input_layer, outputs=encoded)

### Ahora el decoder
decoded = keras.layers.Dense(8, activation='relu')(encoded)
decoded = keras.layers.Dense(16, activation='relu')(decoded)
decoded = keras.layers.Dense(28, activation='linear')(decoded)

# Combinamos ambos modelos
autoencoder = keras.models.Model(input_layer, outputs=decoded)

autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28)]              0
#
#  dense (Dense)               (None, 16)                464
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 5)                 45
#
#  dense_3 (Dense)             (None, 8)                 48
#
#  dense_4 (Dense)             (None, 16)                144
#
#  dense_5 (Dense)             (None, 28)                476
#
# =================================================================
# Total params: 1313 (5.13 KB)
# Trainable params: 1313 (5.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
keras.utils.plot_model(autoencoder, show_shapes=True, rankdir='TD')

# %%
autoencoder.compile(optimizer='rmsprop', loss='mean_squared_error', metrics='mae')

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,
                                                  restore_best_weights=True)

history = autoencoder.fit(X_train, X_train,
                          epochs=1000,
                          batch_size=256,
                          shuffle=True,
                          validation_split=0.2,
                          callbacks=[early_stopping_cb],)
                        #   verbose=False)
# Out:
# Epoch 1/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.9875 - mae: 0.6296 - val_loss: 0.9101 - val_mae: 0.6009
# Epoch 2/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.8405 - mae: 0.5786 - val_loss: 0.7988 - val_mae: 0.5627
# Epoch 3/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.7565 - mae: 0.5495 - val_loss: 0.7299 - val_mae: 0.5356
# Epoch 4/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.6954 - mae: 0.5232 - val_loss: 0.6740 - val_mae: 0.5096
# Epoch 5/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.6450 - mae: 0.4993 - val_loss: 0.6300 - val_mae: 0.4883
# Epoch 6/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.6095 - mae: 0.4825 - val_loss: 0.6018 - val_mae: 0.4765
# Epoch 7/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.5863 - mae: 0.4719 - val_loss: 0.5832 - val_mae: 0.4686
# Epoch 8/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.5688 - mae: 0.4646 - val_loss: 0.5668 - val_mae: 0.4614
# Epoch 9/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.5554 - mae: 0.4587 - val_loss: 0.5559 - val_mae: 0.4581
# Epoch 10/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.5449 - mae: 0.4538 - val_loss: 0.5456 - val_mae: 0.4524
# Epoch 11/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.5363 - mae: 0.4498 - val_loss: 0.5384 - val_mae: 0.4495
# Epoch 12/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.5288 - mae: 0.4465 - val_loss: 0.5338 - val_mae: 0.4478
# Epoch 13/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.5221 - mae: 0.4438 - val_loss: 0.5257 - val_mae: 0.4445
# Epoch 14/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.5158 - mae: 0.4411 - val_loss: 0.5184 - val_mae: 0.4418
# Epoch 15/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.5098 - mae: 0.4389 - val_loss: 0.5135 - val_mae: 0.4416
# Epoch 16/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.5043 - mae: 0.4372 - val_loss: 0.5073 - val_mae: 0.4373
# Epoch 17/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4990 - mae: 0.4352 - val_loss: 0.5038 - val_mae: 0.4381
# Epoch 18/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4943 - mae: 0.4338 - val_loss: 0.4969 - val_mae: 0.4337
# Epoch 19/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.4899 - mae: 0.4322 - val_loss: 0.4927 - val_mae: 0.4336
# Epoch 20/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.4860 - mae: 0.4311 - val_loss: 0.4889 - val_mae: 0.4320
# Epoch 21/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4823 - mae: 0.4298 - val_loss: 0.4856 - val_mae: 0.4306
# Epoch 22/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4790 - mae: 0.4288 - val_loss: 0.4823 - val_mae: 0.4298
# Epoch 23/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4757 - mae: 0.4279 - val_loss: 0.4805 - val_mae: 0.4278
# Epoch 24/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4730 - mae: 0.4269 - val_loss: 0.4764 - val_mae: 0.4264
# Epoch 25/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4698 - mae: 0.4261 - val_loss: 0.4743 - val_mae: 0.4276
# Epoch 26/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4667 - mae: 0.4253 - val_loss: 0.4707 - val_mae: 0.4273
# Epoch 27/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4639 - mae: 0.4248 - val_loss: 0.4722 - val_mae: 0.4301
# Epoch 28/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4610 - mae: 0.4244 - val_loss: 0.4651 - val_mae: 0.4270
# Epoch 29/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4578 - mae: 0.4241 - val_loss: 0.4637 - val_mae: 0.4274
# Epoch 30/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4546 - mae: 0.4242 - val_loss: 0.4594 - val_mae: 0.4259
# Epoch 31/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.4514 - mae: 0.4239 - val_loss: 0.4564 - val_mae: 0.4262
# Epoch 32/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4478 - mae: 0.4235 - val_loss: 0.4511 - val_mae: 0.4246
# Epoch 33/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4444 - mae: 0.4235 - val_loss: 0.4482 - val_mae: 0.4239
# Epoch 34/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4407 - mae: 0.4227 - val_loss: 0.4443 - val_mae: 0.4241
# Epoch 35/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4363 - mae: 0.4223 - val_loss: 0.4451 - val_mae: 0.4273
# Epoch 36/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4329 - mae: 0.4215 - val_loss: 0.4418 - val_mae: 0.4270
# Epoch 37/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4287 - mae: 0.4204 - val_loss: 0.4349 - val_mae: 0.4224
# Epoch 38/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4248 - mae: 0.4191 - val_loss: 0.4316 - val_mae: 0.4220
# Epoch 39/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.4211 - mae: 0.4179 - val_loss: 0.4288 - val_mae: 0.4200
# Epoch 40/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4176 - mae: 0.4168 - val_loss: 0.4323 - val_mae: 0.4243
# Epoch 41/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4144 - mae: 0.4152 - val_loss: 0.4203 - val_mae: 0.4150
# Epoch 42/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4113 - mae: 0.4137 - val_loss: 0.4247 - val_mae: 0.4209
# Epoch 43/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.4088 - mae: 0.4128 - val_loss: 0.4173 - val_mae: 0.4136
# Epoch 44/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.4066 - mae: 0.4118 - val_loss: 0.4191 - val_mae: 0.4174
# Epoch 45/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4044 - mae: 0.4111 - val_loss: 0.4149 - val_mae: 0.4144
# Epoch 46/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4026 - mae: 0.4099 - val_loss: 0.4109 - val_mae: 0.4129
# Epoch 47/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4010 - mae: 0.4094 - val_loss: 0.4072 - val_mae: 0.4093
# Epoch 48/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3993 - mae: 0.4087 - val_loss: 0.4074 - val_mae: 0.4110
# Epoch 49/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3978 - mae: 0.4081 - val_loss: 0.4052 - val_mae: 0.4085
# Epoch 50/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3966 - mae: 0.4076 - val_loss: 0.4060 - val_mae: 0.4094
# Epoch 51/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3952 - mae: 0.4071 - val_loss: 0.4026 - val_mae: 0.4079
# Epoch 52/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3939 - mae: 0.4065 - val_loss: 0.4122 - val_mae: 0.4162
# Epoch 53/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3930 - mae: 0.4062 - val_loss: 0.4026 - val_mae: 0.4092
# Epoch 54/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3918 - mae: 0.4059 - val_loss: 0.4015 - val_mae: 0.4091
# Epoch 55/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3908 - mae: 0.4054 - val_loss: 0.4002 - val_mae: 0.4082
# Epoch 56/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3899 - mae: 0.4050 - val_loss: 0.3964 - val_mae: 0.4066
# Epoch 57/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3889 - mae: 0.4046 - val_loss: 0.3969 - val_mae: 0.4061
# Epoch 58/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3881 - mae: 0.4042 - val_loss: 0.4149 - val_mae: 0.4239
# Epoch 59/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3874 - mae: 0.4040 - val_loss: 0.3977 - val_mae: 0.4076
# Epoch 60/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3867 - mae: 0.4038 - val_loss: 0.3957 - val_mae: 0.4077
# Epoch 61/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3861 - mae: 0.4037 - val_loss: 0.3981 - val_mae: 0.4095
# Epoch 62/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3852 - mae: 0.4034 - val_loss: 0.3954 - val_mae: 0.4052
# Epoch 63/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3848 - mae: 0.4032 - val_loss: 0.3935 - val_mae: 0.4060
# Epoch 64/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3843 - mae: 0.4028 - val_loss: 0.3909 - val_mae: 0.4028
# Epoch 65/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3836 - mae: 0.4025 - val_loss: 0.3912 - val_mae: 0.4032
# Epoch 66/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3832 - mae: 0.4024 - val_loss: 0.3908 - val_mae: 0.4036
# Epoch 67/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3824 - mae: 0.4024 - val_loss: 0.3927 - val_mae: 0.4039
# Epoch 68/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3819 - mae: 0.4020 - val_loss: 0.3895 - val_mae: 0.4026
# Epoch 69/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3817 - mae: 0.4020 - val_loss: 0.3892 - val_mae: 0.4038
# Epoch 70/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3812 - mae: 0.4018 - val_loss: 0.3870 - val_mae: 0.4012
# Epoch 71/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3805 - mae: 0.4016 - val_loss: 0.3913 - val_mae: 0.4072
# Epoch 72/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3800 - mae: 0.4014 - val_loss: 0.3883 - val_mae: 0.4050
# Epoch 73/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3793 - mae: 0.4013 - val_loss: 0.3888 - val_mae: 0.4036
# Epoch 74/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3791 - mae: 0.4012 - val_loss: 0.3856 - val_mae: 0.4016
# Epoch 75/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3786 - mae: 0.4011 - val_loss: 0.3867 - val_mae: 0.4031
# Epoch 76/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3780 - mae: 0.4008 - val_loss: 0.3908 - val_mae: 0.4059
# Epoch 77/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3776 - mae: 0.4006 - val_loss: 0.3970 - val_mae: 0.4148
# Epoch 78/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3774 - mae: 0.4006 - val_loss: 0.3832 - val_mae: 0.4006
# Epoch 79/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3770 - mae: 0.4005 - val_loss: 0.3845 - val_mae: 0.4016
# Epoch 80/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3765 - mae: 0.4004 - val_loss: 0.3848 - val_mae: 0.4029
# Epoch 81/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3762 - mae: 0.4002 - val_loss: 0.3846 - val_mae: 0.4022
# Epoch 82/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3758 - mae: 0.4001 - val_loss: 0.3980 - val_mae: 0.4179
# Epoch 83/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3756 - mae: 0.3998 - val_loss: 0.3842 - val_mae: 0.4028
# Epoch 84/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3753 - mae: 0.3997 - val_loss: 0.3892 - val_mae: 0.4087
# Epoch 85/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3745 - mae: 0.3995 - val_loss: 0.3806 - val_mae: 0.3994
# Epoch 86/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3746 - mae: 0.3996 - val_loss: 0.3813 - val_mae: 0.3996
# Epoch 87/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3739 - mae: 0.3991 - val_loss: 0.3799 - val_mae: 0.4008
# Epoch 88/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3739 - mae: 0.3992 - val_loss: 0.3794 - val_mae: 0.3996
# Epoch 89/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3736 - mae: 0.3991 - val_loss: 0.3871 - val_mae: 0.4066
# Epoch 90/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3732 - mae: 0.3989 - val_loss: 0.3825 - val_mae: 0.4035
# Epoch 91/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3730 - mae: 0.3989 - val_loss: 0.3797 - val_mae: 0.3996
# Epoch 92/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3726 - mae: 0.3986 - val_loss: 0.3797 - val_mae: 0.4012
# Epoch 93/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3724 - mae: 0.3987 - val_loss: 0.3767 - val_mae: 0.3977
# Epoch 94/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3721 - mae: 0.3985 - val_loss: 0.3838 - val_mae: 0.4045
# Epoch 95/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3717 - mae: 0.3982 - val_loss: 0.3892 - val_mae: 0.4087
# Epoch 96/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3716 - mae: 0.3982 - val_loss: 0.3813 - val_mae: 0.4021
# Epoch 97/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3712 - mae: 0.3979 - val_loss: 0.3855 - val_mae: 0.4068
# Epoch 98/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3709 - mae: 0.3980 - val_loss: 0.3806 - val_mae: 0.4005
# Epoch 99/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3709 - mae: 0.3979 - val_loss: 0.3746 - val_mae: 0.3980
# Epoch 100/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3704 - mae: 0.3977 - val_loss: 0.3809 - val_mae: 0.4029
# Epoch 101/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3699 - mae: 0.3976 - val_loss: 0.3782 - val_mae: 0.4006
# Epoch 102/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3698 - mae: 0.3973 - val_loss: 0.3779 - val_mae: 0.4000
# Epoch 103/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3692 - mae: 0.3974 - val_loss: 0.3767 - val_mae: 0.3994
# Epoch 104/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3691 - mae: 0.3972 - val_loss: 0.3731 - val_mae: 0.3975
# Epoch 105/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3687 - mae: 0.3973 - val_loss: 0.3763 - val_mae: 0.3994
# Epoch 106/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3688 - mae: 0.3972 - val_loss: 0.3830 - val_mae: 0.4048
# Epoch 107/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3682 - mae: 0.3970 - val_loss: 0.3799 - val_mae: 0.4067
# Epoch 108/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3683 - mae: 0.3972 - val_loss: 0.3737 - val_mae: 0.3992
# Epoch 109/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3678 - mae: 0.3970 - val_loss: 0.3716 - val_mae: 0.3963
# Epoch 110/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3680 - mae: 0.3969 - val_loss: 0.3757 - val_mae: 0.4016
# Epoch 111/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3674 - mae: 0.3967 - val_loss: 0.3736 - val_mae: 0.3982
# Epoch 112/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3671 - mae: 0.3968 - val_loss: 0.3754 - val_mae: 0.4014
# Epoch 113/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3667 - mae: 0.3966 - val_loss: 0.3709 - val_mae: 0.3965
# Epoch 114/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3659 - mae: 0.3962 - val_loss: 0.3779 - val_mae: 0.4025
# Epoch 115/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3658 - mae: 0.3962 - val_loss: 0.3710 - val_mae: 0.3964
# Epoch 116/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3657 - mae: 0.3960 - val_loss: 0.3699 - val_mae: 0.3962
# Epoch 117/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3653 - mae: 0.3960 - val_loss: 0.3694 - val_mae: 0.3960
# Epoch 118/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3648 - mae: 0.3959 - val_loss: 0.3741 - val_mae: 0.4004
# Epoch 119/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3646 - mae: 0.3956 - val_loss: 0.3709 - val_mae: 0.3992
# Epoch 120/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3642 - mae: 0.3956 - val_loss: 0.3679 - val_mae: 0.3959
# Epoch 121/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3636 - mae: 0.3956 - val_loss: 0.3671 - val_mae: 0.3954
# Epoch 122/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3634 - mae: 0.3955 - val_loss: 0.3686 - val_mae: 0.3981
# Epoch 123/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3630 - mae: 0.3953 - val_loss: 0.3669 - val_mae: 0.3963
# Epoch 124/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3632 - mae: 0.3952 - val_loss: 0.3674 - val_mae: 0.3959
# Epoch 125/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3624 - mae: 0.3952 - val_loss: 0.3703 - val_mae: 0.3997
# Epoch 126/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3622 - mae: 0.3951 - val_loss: 0.3697 - val_mae: 0.3992
# Epoch 127/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3618 - mae: 0.3952 - val_loss: 0.3656 - val_mae: 0.3972
# Epoch 128/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3615 - mae: 0.3949 - val_loss: 0.3681 - val_mae: 0.3994
# Epoch 129/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3611 - mae: 0.3950 - val_loss: 0.3719 - val_mae: 0.4018
# Epoch 130/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3607 - mae: 0.3950 - val_loss: 0.3667 - val_mae: 0.3977
# Epoch 131/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3607 - mae: 0.3946 - val_loss: 0.3689 - val_mae: 0.3982
# Epoch 132/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3604 - mae: 0.3943 - val_loss: 0.3676 - val_mae: 0.3985
# Epoch 133/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3602 - mae: 0.3944 - val_loss: 0.3646 - val_mae: 0.3957
# Epoch 134/1000
# 157/157 [==============================] - 2s 15ms/step - loss: 0.3599 - mae: 0.3944 - val_loss: 0.3676 - val_mae: 0.3999
# Epoch 135/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3592 - mae: 0.3943 - val_loss: 0.3717 - val_mae: 0.4015
# Epoch 136/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3592 - mae: 0.3941 - val_loss: 0.3694 - val_mae: 0.4000
# Epoch 137/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3588 - mae: 0.3941 - val_loss: 0.3623 - val_mae: 0.3955
# Epoch 138/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3583 - mae: 0.3940 - val_loss: 0.3634 - val_mae: 0.3963
# Epoch 139/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3580 - mae: 0.3940 - val_loss: 0.3618 - val_mae: 0.3968
# Epoch 140/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3579 - mae: 0.3938 - val_loss: 0.3638 - val_mae: 0.3974
# Epoch 141/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3576 - mae: 0.3938 - val_loss: 0.3627 - val_mae: 0.3978
# Epoch 142/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3571 - mae: 0.3935 - val_loss: 0.3604 - val_mae: 0.3951
# Epoch 143/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3568 - mae: 0.3935 - val_loss: 0.3644 - val_mae: 0.3974
# Epoch 144/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3566 - mae: 0.3937 - val_loss: 0.3596 - val_mae: 0.3960
# Epoch 145/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3563 - mae: 0.3936 - val_loss: 0.3600 - val_mae: 0.3947
# Epoch 146/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3559 - mae: 0.3934 - val_loss: 0.3664 - val_mae: 0.4031
# Epoch 147/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3557 - mae: 0.3933 - val_loss: 0.3624 - val_mae: 0.3967
# Epoch 148/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3554 - mae: 0.3932 - val_loss: 0.3599 - val_mae: 0.3965
# Epoch 149/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3554 - mae: 0.3933 - val_loss: 0.3595 - val_mae: 0.3933
# Epoch 150/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3549 - mae: 0.3931 - val_loss: 0.3585 - val_mae: 0.3948
# Epoch 151/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3547 - mae: 0.3930 - val_loss: 0.3594 - val_mae: 0.3953
# Epoch 152/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3542 - mae: 0.3929 - val_loss: 0.3621 - val_mae: 0.3978
# Epoch 153/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3543 - mae: 0.3929 - val_loss: 0.3546 - val_mae: 0.3911
# Epoch 154/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3538 - mae: 0.3926 - val_loss: 0.3592 - val_mae: 0.3961
# Epoch 155/1000
# 157/157 [==============================] - 1s 4ms/step - loss: 0.3537 - mae: 0.3926 - val_loss: 0.3558 - val_mae: 0.3927
# Epoch 156/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3532 - mae: 0.3923 - val_loss: 0.3556 - val_mae: 0.3941
# Epoch 157/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3531 - mae: 0.3923 - val_loss: 0.3543 - val_mae: 0.3917
# Epoch 158/1000
# 157/157 [==============================] - 1s 6ms/step - loss: 0.3524 - mae: 0.3921 - val_loss: 0.3567 - val_mae: 0.3939
# Epoch 159/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3522 - mae: 0.3920 - val_loss: 0.3589 - val_mae: 0.3959
# Epoch 160/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3524 - mae: 0.3919 - val_loss: 0.3530 - val_mae: 0.3907
# Epoch 161/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3518 - mae: 0.3919 - val_loss: 0.3592 - val_mae: 0.3988
# Epoch 162/1000
# 157/157 [==============================] - 1s 6ms/step - loss: 0.3516 - mae: 0.3920 - val_loss: 0.3577 - val_mae: 0.3957
# Epoch 163/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3513 - mae: 0.3919 - val_loss: 0.3556 - val_mae: 0.3921
# Epoch 164/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3513 - mae: 0.3919 - val_loss: 0.3520 - val_mae: 0.3915
# Epoch 165/1000
# 157/157 [==============================] - 1s 3ms/step - loss: 0.3509 - mae: 0.3915 - val_loss: 0.3535 - val_mae: 0.3933
# Epoch 166/1000
# 157/157 [==============================] - 1s 5ms/step - loss: 0.3507 - mae: 0.3915 - val_loss: 0.3518 - val_mae: 0.3922
# Epoch 167/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3503 - mae: 0.3914 - val_loss: 0.3532 - val_mae: 0.3931
# Epoch 168/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3502 - mae: 0.3913 - val_loss: 0.3515 - val_mae: 0.3915
# Epoch 169/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3500 - mae: 0.3911 - val_loss: 0.3562 - val_mae: 0.3966
# Epoch 170/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3499 - mae: 0.3914 - val_loss: 0.3489 - val_mae: 0.3897
# Epoch 171/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3494 - mae: 0.3910 - val_loss: 0.3532 - val_mae: 0.3947
# Epoch 172/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3495 - mae: 0.3912 - val_loss: 0.3547 - val_mae: 0.3945
# Epoch 173/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3491 - mae: 0.3909 - val_loss: 0.3561 - val_mae: 0.3949
# Epoch 174/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3488 - mae: 0.3910 - val_loss: 0.3566 - val_mae: 0.3972
# Epoch 175/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3487 - mae: 0.3909 - val_loss: 0.3494 - val_mae: 0.3908
# Epoch 176/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3484 - mae: 0.3907 - val_loss: 0.3547 - val_mae: 0.3926
# Epoch 177/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3481 - mae: 0.3904 - val_loss: 0.3496 - val_mae: 0.3898
# Epoch 178/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3478 - mae: 0.3904 - val_loss: 0.3498 - val_mae: 0.3897
# Epoch 179/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3478 - mae: 0.3904 - val_loss: 0.3534 - val_mae: 0.3937
# Epoch 180/1000
# 157/157 [==============================] - 0s 3ms/step - loss: 0.3475 - mae: 0.3902 - val_loss: 0.3559 - val_mae: 0.3959

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

kw = {'marker': '.', 'lw': 2, 'alpha': 0.5}
ll0, = ax.plot(history.history['loss'], ls=':', color='C0', label='Train Loss', **kw)
ll1, = ax.plot(history.history['val_loss'], ls=':', color='C1', label='Validation Loss', **kw)

ax.set_ylabel('Pérdida', fontsize=16)

# ax.legend(handles=[l0, l1, ll0, ll1], loc='center', fontsize=14)
# plt.legend(loc=0)
# Out:
# Text(0, 0.5, 'Pérdida')

# %% [markdown]
# Salvamos los modelos.

# %%
autoencoder.save('models/autoencoder_notebook10.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
encoder.save('models/encoder_notebook10.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Detección de anomalías

# %% [markdown]
# ### Mirando los códigos

# %% [markdown]
# Calculamos los códigos del conjunto de entrenamiento y de testeo y vemos si tienen una distribución muy diferente.
#
# La codificación se obtiene con el `encoder`, que habíamos separado, y que fue entrenado a la vez que el `autoencoder`. Necesitamos usar el método `predict`.

# %%
codes_train = encoder.predict(X_train)
print(codes_train.shape)
# Out:
# 1563/1563 [==============================] - 2s 1ms/step
# (50000, 5)

# %% [markdown]
# Calculemos ahora los códigos del conjunto de testeo

# %%
codes_test = encoder.predict(X_test)
print(codes_test.shape)
# Out:
# 1793/1793 [==============================] - 6s 3ms/step
# (57355, 5)

# %% [markdown]
# Como se trata de vectores de dos dimensiones, podemos fácilmente graficarlos en el plano.

# %%
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(111)

# ax.hexbin(codes_train[:, 0], codes_train[:, 1], gridsize=40, cmap='gray_r')
ax.plot(*codes_train.T, ',', alpha=0.9)
ax.plot(*codes_test.T, ',', alpha=0.1)
# Out:
# [<matplotlib.lines.Line2D at 0x7ab79dcb6140>,
#  <matplotlib.lines.Line2D at 0x7ab79dcb6230>,
#  <matplotlib.lines.Line2D at 0x7ab79dcb6320>]

# %% [markdown]
# A simple vista, no vemos de manera clara que haya puntos naranjas fuera de la distribución. Si los datos anómalos son muy poco numerosos, no esperamos que sea manera sea fácil detectar las transacciones fraudulentas.

# %%
# Cálculo la media de los códigos en entrenamiento
mean_codes = np.mean(codes_train, axis=0)

# Y las distancias a los códigos de test
mae_test = tf.keras.losses.mae(mean_codes, codes_test)

# %% [markdown]
# Ahora calculamos el límite de la distancia

# %%
# Check the prediction loss threshold for 2% of outliers
distance_threshold = np.percentile(mae_test, 98)
print(f'El umbral de distancia al centro de los codings es {distance_threshold:.2f}')
# Out:
# El umbral de distancia al centro de los codings es 0.29

# %%
import seaborn as sns
sns.histplot(mae_test, bins=100, alpha=0.8)
plt.axvline(x=distance_threshold, color='orange')

# %%
y_test_dist = mae_test.numpy() >= distance_threshold

# %% [markdown]
# Ahora tenemos la predicción y la etiqueta verdadera. Podemos calcular la matriz de confusión

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(t_test, y_test_dist))
print(classification_report(t_test, y_test_dist))
# Out:
# [[55811  1052]
#  [  396    96]]
#               precision    recall  f1-score   support
#
#        False       0.99      0.98      0.99     56863
#         True       0.08      0.20      0.12       492
#
#     accuracy                           0.97     57355
#    macro avg       0.54      0.59      0.55     57355
# weighted avg       0.99      0.97      0.98     57355

# %% [markdown]
# Vemos que este approach no es muy bueno en este caso, y produce un F1 de menos de 10%.

# %% [markdown]
# ### Mirando el error de reconstrucción

# %% [markdown]
# Otra opción es mirar el **error de reconstrucción**

# %%
prediction = autoencoder.predict(X_test)

prediction_loss = tf.keras.losses.mae(prediction, X_test)

# Check the prediction loss threshold for 2% of outliers
loss_threshold = np.percentile(prediction_loss, 98)
print(f'El umbral de pérdida elegido es {loss_threshold:.2f}')
# Out:
# 1793/1793 [==============================] - 3s 2ms/step
# El umbral de pérdida elegido es 0.95

# %%
import seaborn as sns
sns.histplot(prediction_loss, bins=100, alpha=0.8)
plt.axvline(x=loss_threshold, color='orange')

# %% [markdown]
# Vamos a definir a todas las instancias que estén por arriba de 1.2 como outliers.

# %%
y_test = prediction_loss.numpy() >= loss_threshold

# %% [markdown]
# Ahora tenemos la predicción y la etiqueta verdadera. Podemos calcular la matriz de confusión

# %%
print(confusion_matrix(t_test, y_test))
print(classification_report(t_test, y_test))
# Out:
# [[56127   736]
#  [   80   412]]
#               precision    recall  f1-score   support
#
#        False       1.00      0.99      0.99     56863
#         True       0.36      0.84      0.50       492
#
#     accuracy                           0.99     57355
#    macro avg       0.68      0.91      0.75     57355
# weighted avg       0.99      0.99      0.99     57355

# %%
2* (0.35 * 0.82 ) / (0.35 + 0.82)
# Out:
# 0.4905982905982906

# %% [markdown]
# Y también podemos ver cómo cambian las métricas a medida que cambiamos el umbral de clasificación (recuerden que eso lo fijamos arriba a 1.2). Para eso, graficamos la curva ROC y calculamos el área bajo la curva.

# %%
from sklearn.metrics import roc_curve, roc_auc_score

fpr_d, tpr_d, thr = roc_curve(t_test, mae_test)
auc_dist = roc_auc_score(t_test, mae_test)
print(f'Area bajo la curva (distancia): {auc_dist:.2f}')


fpr, tpr, thr = roc_curve(t_test, prediction_loss)
auc_loss = roc_auc_score(t_test, prediction_loss)
print(f'Area bajo la curva (pérdida): {auc_loss:.2f}')


fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

# Plot curves
_ = ax.plot([0, 1], [0, 1], ls=':', color='0.5')
_ = ax.plot(fpr, tpr, '.', lw=5, label=f'Pérdida (AUC = {auc_loss:.2f})')
_ = ax.plot(fpr_d, tpr_d, '.', lw=5, label=f'Códigos (AUC = {auc_dist:.2f})')

# Labels
_ = ax.set_xlabel('Tasa de falsos positivos', fontsize=16)
_ = ax.set_ylabel('Tasa de verdaderos positivos', fontsize=16)

_ = ax.legend(loc=0, fontsize=16)
# Out:
# Area bajo la curva (distancia): 0.73
# Area bajo la curva (pérdida): 0.96

# %% [markdown]
# Vemos que el autoencoder tiene capacidad de separar correctamente las transacciones fraudulentas cuando usamos como métrica el error de reconstrucción. Aunque la precisión del método no sea tan buena.
#
# En el ejercicio de esta semana, van a intentar mejorar la performance del algoritmo cambiando ligeramente la arquitecutra de la red.
